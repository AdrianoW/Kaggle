# %%
import pandas as pd

# %%
out1 = pd.read_csv('../Out/xgb3_all.csv')
out2 = pd.read_csv('../Out/xgb_e.01_md16_ss.95_byt.8_aph.0001_lamb1.csv')
out3 = pd.read_csv('../Out/xgb_e.01_md16_ss.95_byt.8_aph.0001_lamb1_nodate.csv')

# %%
final_out = pd.DataFrame(dict(target=(0.25*out1.target + 0.35*out2.target + 0.4*out3.target), ID=out1.ID))

# %%
final_out.to_csv('./bagged_weigthed.csv', index=False)

# %%
out1
# Out:
#             ID    target
# 0            1  0.333050
# 1            3  0.304718
# 2            6  0.142193
# 3            9  0.168519
# 4           10  0.634349
# 5           11  0.037148
# 6           12  0.013622
# 7           13  0.025913
# 8           15  0.082886
# 9           17  0.019507
# 10          18  0.719901
# 11          19  0.029768
# 12          27  0.118372
# 13          29  0.008341
# 14          33  0.649688
# 15          34  0.010885
# 16          39  0.088580
# 17          41  0.038887
# 18          44  0.014174
# 19          45  0.323417
# 20          47  0.072761
# 21          48  0.011090
# 22          49  0.105872
# 23          53  0.032794
# 24          56  0.029029
# 25          57  0.160334
# 26          59  0.013572
# 27          61  0.040554
# 28          64  0.013704
# 29          68  0.035146
# ...        ...       ...
# 145202  290400  0.025312
# 145203  290401  0.010096
# 145204  290403  0.973574
# 145205  290406  0.030879
# 145206  290408  0.250124
# ...

# %%
[ '{}_{}_{}'.format(1,1,col) for col in out1.columns.tolist() ]
# Out:
# ['1_1_ID', '1_1_target']
