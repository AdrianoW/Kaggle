# %% [markdown]
# #ML Search
#
# To make sure that the first search was ok, the search is run again. This time, the validation dataset is the test set and a new validation was used. That means that the dataset was split:
#
#     - Train_big
#         - Train
#         - Validation
#     - Test

# %%
# %pylab inline
import sklearn
import pandas as pd
import mylib.utils as mu
from itertools import combinations 
import seaborn as sns
from mylib.utils import print_time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
groups = ['balance', 'location', 'nu_info', 'personal', 'raw_scores', 'scores_class']
all_combinations = [ p for i in range(len(groups)) for p in combinations(groups, i)][1:]
target = mu.load_target_data()

# %% [markdown]
# ### Search over all combinations

# %%
proc_name = 'combination'
best_score = 0
best_run = None
best_models = {}
for comb in all_combinations:
    # load only the data from the combination
    print_time('Processing combination {}'.format(comb))
    data = mu.load_data(comb)
    
    # create test set
    X_train, X_test, y_train, y_test = mu.split_data(data, target)
    print_time('Test shape {}'.format(X_test.shape))
    
    results = mu.train_regression(X_train, mu.np.ravel(y_train), scorer=mu.f1_scorer)
    
    # evaluate the best model agains the test set
    run =  results[0][1]
    model = run['model']
    run['comb'] = comb
    score_val = run['score_val']
    print_time('Val score {}'.format(score_val))
    pred_test = model.predict(X_test)
    score_test = mu.f1_scorer(y_test, pred_test)
    run['score_test'] = score_test
    run['pred_test'] = pred_test
    run['y_test'] = y_test
    
    # save the best model
    if best_score<score_test:
        best_score = score_test
        best_run = run
    
    # save models with score test more than .65
    best_models[score_test] = run
# Out:
# 03:24:34 10/08/15 BRT - Processing combination ('balance',)
# 03:24:34 10/08/15 BRT - Test shape (64, 9)
# 03:24:34 10/08/15 BRT - Created train and validation
# 03:24:34 10/08/15 BRT - Size train: (513, 9) test:(57, 9)
# 03:24:34 10/08/15 BRT - Starting to train models
# 03:24:34 10/08/15 BRT - Took 0.248217105865 seconds
# 03:24:34 10/08/15 BRT - Val score 0.533245987553
# 03:24:34 10/08/15 BRT - Processing combination ('location',)
# 03:24:34 10/08/15 BRT - Test shape (64, 246)
# 03:24:34 10/08/15 BRT - Created train and validation
# 03:24:34 10/08/15 BRT - Size train: (513, 246) test:(57, 246)
# 03:24:34 10/08/15 BRT - Starting to train models
# 03:24:35 10/08/15 BRT - Took 0.998915910721 seconds
# 03:24:35 10/08/15 BRT - Val score 0.541062801932
# 03:24:35 10/08/15 BRT - Processing combination ('nu_info',)
# 03:24:35 10/08/15 BRT - Test shape (64, 8)
# 03:24:35 10/08/15 BRT - Created train and validation
# 03:24:35 10/08/15 BRT - Size train: (513, 8) test:(57, 8)
# 03:24:35 10/08/15 BRT - Starting to train models
# 03:24:35 10/08/15 BRT - Took 0.292543888092 seconds
# 03:24:35 10/08/15 BRT - Val score 0.511273420133
# 03:24:35 10/08/15 BRT - Processing combination ('personal',)
# 03:24:35 10/08/15 BRT - Test shape (64, 22)
# 03:24:35 10/08/15 BRT - Created train and validation
# 03:24:35 10/08/15 BRT - Size train: (513, 22) test:(57, 22)
# 03:24:35 10/08/15 BRT - Starting to train models
# 03:24:36 10/08/15 BRT - Took 0.444851160049 seconds
# 03:24:36 10/08/15 BRT - Val score 0.541062801932
# 03:24:36 10/08/15 BRT - Processing combination ('raw_scores',)
# 03:24:36 10/08/15 BRT - Test shape (64, 5)
# 03:24:36 10/08/15 BRT - Created train and validation
# 03:24:36 10/08/15 BRT - Size train: (513, 5) test:(57, 5)
# 03:24:36 10/08/15 BRT - Starting to train models
# 03:24:36 10/08/15 BRT - Took 0.249356031418 seconds
# 03:24:36 10/08/15 BRT - Val score 0.62987012987
# 03:24:36 10/08/15 BRT - Processing combination ('scores_class',)
# 03:24:36 10/08/15 BRT - Test shape (64, 4)
# 03:24:36 10/08/15 BRT - Created train and validation
# 03:24:36 10/08/15 BRT - Size train: (513, 4) test:(57, 4)
# 03:24:36 10/08/15 BRT - Starting to train models
# 03:24:36 10/08/15 BRT - Took 0.288557052612 seconds
# 03:24:36 10/08/15 BRT - Val score 0.561977948547
# 03:24:36 10/08/15 BRT - Processing combination ('balance', 'location')
# 03:24:36 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:24:36 10/08/15 BRT - Test shape (64, 255)
# 03:24:36 10/08/15 BRT - Created train and validation
# 03:24:36 10/08/15 BRT - Size train: (513, 255) test:(57, 255)
# 03:24:36 10/08/15 BRT - Starting to train models
# 03:24:37 10/08/15 BRT - Took 0.785115003586 seconds
# 03:24:37 10/08/15 BRT - Val score 0.533245987553
# 03:24:37 10/08/15 BRT - Processing combination ('balance', 'nu_info')
# 03:24:37 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:24:37 10/08/15 BRT - Test shape (64, 17)
# 03:24:37 10/08/15 BRT - Created train and validation
# 03:24:37 10/08/15 BRT - Size train: (513, 17) test:(57, 17)
# 03:24:37 10/08/15 BRT - Starting to train models
# 03:24:37 10/08/15 BRT - Took 0.337438106537 seconds
# 03:24:37 10/08/15 BRT - Val score 0.559232910609
# 03:24:37 10/08/15 BRT - Processing combination ('balance', 'personal')
# 03:24:37 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 03:24:37 10/08/15 BRT - Test shape (64, 31)
# 03:24:37 10/08/15 BRT - Created train and validation
# 03:24:37 10/08/15 BRT - Size train: (513, 31) test:(57, 31)
# 03:24:37 10/08/15 BRT - Starting to train models
# 03:24:38 10/08/15 BRT - Took 0.373109817505 seconds
# 03:24:38 10/08/15 BRT - Val score 0.547475389012
# 03:24:38 10/08/15 BRT - Processing combination ('balance', 'raw_scores')
# 03:24:38 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 15)
# 03:24:38 10/08/15 BRT - Test shape (64, 14)
# 03:24:38 10/08/15 BRT - Created train and validation
# 03:24:38 10/08/15 BRT - Size train: (513, 14) test:(57, 14)
# 03:24:38 10/08/15 BRT - Starting to train models
# 03:24:38 10/08/15 BRT - Took 0.376396894455 seconds
# 03:24:38 10/08/15 BRT - Val score 0.555844155844
# 03:24:38 10/08/15 BRT - Processing combination ('balance', 'scores_class')
# 03:24:38 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 14)
# 03:24:38 10/08/15 BRT - Test shape (64, 13)
# 03:24:38 10/08/15 BRT - Created train and validation
# 03:24:38 10/08/15 BRT - Size train: (513, 13) test:(57, 13)
# 03:24:38 10/08/15 BRT - Starting to train models
# 03:24:39 10/08/15 BRT - Took 0.350290060043 seconds
# 03:24:39 10/08/15 BRT - Val score 0.542592592593
# 03:24:39 10/08/15 BRT - Processing combination ('location', 'nu_info')
# 03:24:39 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:24:39 10/08/15 BRT - Test shape (64, 254)
# 03:24:39 10/08/15 BRT - Created train and validation
# 03:24:39 10/08/15 BRT - Size train: (513, 254) test:(57, 254)
# 03:24:39 10/08/15 BRT - Starting to train models
# 03:24:40 10/08/15 BRT - Took 0.926296949387 seconds
# 03:24:40 10/08/15 BRT - Val score 0.64375
# 03:24:40 10/08/15 BRT - Processing combination ('location', 'personal')
# 03:24:40 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 03:24:40 10/08/15 BRT - Test shape (64, 268)
# 03:24:40 10/08/15 BRT - Created train and validation
# 03:24:40 10/08/15 BRT - Size train: (513, 268) test:(57, 268)
# 03:24:40 10/08/15 BRT - Starting to train models
# 03:24:41 10/08/15 BRT - Took 1.79536604881 seconds
# 03:24:41 10/08/15 BRT - Val score 0.533245987553
# 03:24:41 10/08/15 BRT - Processing combination ('location', 'raw_scores')
# 03:24:41 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 252)
# 03:24:41 10/08/15 BRT - Test shape (64, 251)
# 03:24:41 10/08/15 BRT - Created train and validation
# 03:24:41 10/08/15 BRT - Size train: (513, 251) test:(57, 251)
# 03:24:41 10/08/15 BRT - Starting to train models
# 03:24:43 10/08/15 BRT - Took 1.34651899338 seconds
# 03:24:43 10/08/15 BRT - Val score 0.588383045526
# 03:24:43 10/08/15 BRT - Processing combination ('location', 'scores_class')
# 03:24:43 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 251)
# 03:24:43 10/08/15 BRT - Test shape (64, 250)
# 03:24:43 10/08/15 BRT - Created train and validation
# 03:24:43 10/08/15 BRT - Size train: (513, 250) test:(57, 250)
# 03:24:43 10/08/15 BRT - Starting to train models
# 03:24:45 10/08/15 BRT - Took 1.68270778656 seconds
# 03:24:45 10/08/15 BRT - Val score 0.547475389012
# 03:24:45 10/08/15 BRT - Processing combination ('nu_info', 'personal')
# 03:24:45 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 03:24:45 10/08/15 BRT - Test shape (64, 30)
# 03:24:45 10/08/15 BRT - Created train and validation
# 03:24:45 10/08/15 BRT - Size train: (513, 30) test:(57, 30)
# 03:24:45 10/08/15 BRT - Starting to train models
# 03:24:45 10/08/15 BRT - Took 0.429412126541 seconds
# 03:24:45 10/08/15 BRT - Val score 0.5725
# 03:24:45 10/08/15 BRT - Processing combination ('nu_info', 'raw_scores')
# 03:24:45 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 14)
# 03:24:45 10/08/15 BRT - Test shape (64, 13)
# 03:24:45 10/08/15 BRT - Created train and validation
# 03:24:45 10/08/15 BRT - Size train: (513, 13) test:(57, 13)
# 03:24:45 10/08/15 BRT - Starting to train models
# 03:24:45 10/08/15 BRT - Took 0.359781980515 seconds
# 03:24:45 10/08/15 BRT - Val score 0.541062801932
# 03:24:45 10/08/15 BRT - Processing combination ('nu_info', 'scores_class')
# 03:24:45 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 13)
# 03:24:45 10/08/15 BRT - Test shape (64, 12)
# 03:24:45 10/08/15 BRT - Created train and validation
# 03:24:45 10/08/15 BRT - Size train: (513, 12) test:(57, 12)
# 03:24:45 10/08/15 BRT - Starting to train models
# 03:24:46 10/08/15 BRT - Took 0.367708921432 seconds
# 03:24:46 10/08/15 BRT - Val score 0.533245987553
# 03:24:46 10/08/15 BRT - Processing combination ('personal', 'raw_scores')
# 03:24:46 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 28)
# 03:24:46 10/08/15 BRT - Test shape (64, 27)
# 03:24:46 10/08/15 BRT - Created train and validation
# 03:24:46 10/08/15 BRT - Size train: (513, 27) test:(57, 27)
# 03:24:46 10/08/15 BRT - Starting to train models
# 03:24:46 10/08/15 BRT - Took 0.633857965469 seconds
# 03:24:46 10/08/15 BRT - Val score 0.555844155844
# 03:24:46 10/08/15 BRT - Processing combination ('personal', 'scores_class')
# 03:24:46 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 27)
# 03:24:46 10/08/15 BRT - Test shape (64, 26)
# 03:24:46 10/08/15 BRT - Created train and validation
# 03:24:46 10/08/15 BRT - Size train: (513, 26) test:(57, 26)
# 03:24:46 10/08/15 BRT - Starting to train models
# 03:24:47 10/08/15 BRT - Took 0.775042057037 seconds
# 03:24:47 10/08/15 BRT - Val score 0.552590266876
# 03:24:47 10/08/15 BRT - Processing combination ('raw_scores', 'scores_class')
# 03:24:47 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 10)
# 03:24:47 10/08/15 BRT - Test shape (64, 9)
# 03:24:47 10/08/15 BRT - Created train and validation
# 03:24:47 10/08/15 BRT - Size train: (513, 9) test:(57, 9)
# 03:24:47 10/08/15 BRT - Starting to train models
# 03:24:48 10/08/15 BRT - Took 0.485952854156 seconds
# 03:24:48 10/08/15 BRT - Val score 0.543719211823
# 03:24:48 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info')
# 03:24:48 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:24:48 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:24:48 10/08/15 BRT - Test shape (64, 263)
# 03:24:48 10/08/15 BRT - Created train and validation
# 03:24:48 10/08/15 BRT - Size train: (513, 263) test:(57, 263)
# 03:24:48 10/08/15 BRT - Starting to train models
# 03:24:49 10/08/15 BRT - Took 0.968487024307 seconds
# 03:24:49 10/08/15 BRT - Val score 0.583677357891
# 03:24:49 10/08/15 BRT - Processing combination ('balance', 'location', 'personal')
# 03:24:49 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:24:49 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 03:24:49 10/08/15 BRT - Test shape (64, 277)
# 03:24:49 10/08/15 BRT - Created train and validation
# 03:24:49 10/08/15 BRT - Size train: (513, 277) test:(57, 277)
# 03:24:49 10/08/15 BRT - Starting to train models
# 03:24:50 10/08/15 BRT - Took 1.02241611481 seconds
# 03:24:50 10/08/15 BRT - Val score 0.551794871795
# 03:24:50 10/08/15 BRT - Processing combination ('balance', 'location', 'raw_scores')
# 03:24:50 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:24:50 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 261)
# 03:24:50 10/08/15 BRT - Test shape (64, 260)
# 03:24:50 10/08/15 BRT - Created train and validation
# 03:24:50 10/08/15 BRT - Size train: (513, 260) test:(57, 260)
# 03:24:50 10/08/15 BRT - Starting to train models
# 03:24:51 10/08/15 BRT - Took 0.980560064316 seconds
# 03:24:51 10/08/15 BRT - Val score 0.552590266876
# 03:24:51 10/08/15 BRT - Processing combination ('balance', 'location', 'scores_class')
# 03:24:51 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:24:51 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 260)
# 03:24:51 10/08/15 BRT - Test shape (64, 259)
# 03:24:51 10/08/15 BRT - Created train and validation
# 03:24:51 10/08/15 BRT - Size train: (513, 259) test:(57, 259)
# 03:24:51 10/08/15 BRT - Starting to train models
# 03:24:52 10/08/15 BRT - Took 1.06316304207 seconds
# 03:24:52 10/08/15 BRT - Val score 0.540322580645
# 03:24:52 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'personal')
# 03:24:52 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:24:52 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 03:24:52 10/08/15 BRT - Test shape (64, 39)
# 03:24:52 10/08/15 BRT - Created train and validation
# 03:24:52 10/08/15 BRT - Size train: (513, 39) test:(57, 39)
# 03:24:52 10/08/15 BRT - Starting to train models
# 03:24:53 10/08/15 BRT - Took 0.511391878128 seconds
# 03:24:53 10/08/15 BRT - Val score 0.570586308549
# 03:24:53 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'raw_scores')
# 03:24:53 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:24:53 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 23)
# 03:24:53 10/08/15 BRT - Test shape (64, 22)
# 03:24:53 10/08/15 BRT - Created train and validation
# 03:24:53 10/08/15 BRT - Size train: (513, 22) test:(57, 22)
# 03:24:53 10/08/15 BRT - Starting to train models
# 03:24:53 10/08/15 BRT - Took 0.423322916031 seconds
# 03:24:53 10/08/15 BRT - Val score 0.591970121382
# 03:24:53 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'scores_class')
# 03:24:53 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:24:53 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 22)
# 03:24:53 10/08/15 BRT - Test shape (64, 21)
# 03:24:53 10/08/15 BRT - Created train and validation
# 03:24:53 10/08/15 BRT - Size train: (513, 21) test:(57, 21)
# 03:24:53 10/08/15 BRT - Starting to train models
# 03:24:53 10/08/15 BRT - Took 0.449991941452 seconds
# 03:24:53 10/08/15 BRT - Val score 0.568181818182
# 03:24:53 10/08/15 BRT - Processing combination ('balance', 'personal', 'raw_scores')
# 03:24:54 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 03:24:54 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 37)
# 03:24:54 10/08/15 BRT - Test shape (64, 36)
# 03:24:54 10/08/15 BRT - Created train and validation
# 03:24:54 10/08/15 BRT - Size train: (513, 36) test:(57, 36)
# 03:24:54 10/08/15 BRT - Starting to train models
# 03:24:54 10/08/15 BRT - Took 0.509680986404 seconds
# 03:24:54 10/08/15 BRT - Val score 0.532196969697
# 03:24:54 10/08/15 BRT - Processing combination ('balance', 'personal', 'scores_class')
# 03:24:54 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 03:24:54 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 36)
# 03:24:54 10/08/15 BRT - Test shape (64, 35)
# 03:24:54 10/08/15 BRT - Created train and validation
# 03:24:54 10/08/15 BRT - Size train: (513, 35) test:(57, 35)
# 03:24:54 10/08/15 BRT - Starting to train models
# 03:24:55 10/08/15 BRT - Took 0.450443029404 seconds
# 03:24:55 10/08/15 BRT - Val score 0.562659846547
# 03:24:55 10/08/15 BRT - Processing combination ('balance', 'raw_scores', 'scores_class')
# 03:24:55 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 15)
# 03:24:55 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 19)
# 03:24:55 10/08/15 BRT - Test shape (64, 18)
# 03:24:55 10/08/15 BRT - Created train and validation
# 03:24:55 10/08/15 BRT - Size train: (513, 18) test:(57, 18)
# 03:24:55 10/08/15 BRT - Starting to train models
# 03:24:55 10/08/15 BRT - Took 0.355861902237 seconds
# 03:24:55 10/08/15 BRT - Val score 0.568181818182
# 03:24:55 10/08/15 BRT - Processing combination ('location', 'nu_info', 'personal')
# 03:24:55 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:24:55 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 03:24:55 10/08/15 BRT - Test shape (64, 276)
# 03:24:55 10/08/15 BRT - Created train and validation
# 03:24:55 10/08/15 BRT - Size train: (513, 276) test:(57, 276)
# 03:24:55 10/08/15 BRT - Starting to train models
# 03:24:56 10/08/15 BRT - Took 1.29863500595 seconds
# 03:24:56 10/08/15 BRT - Val score 0.614492753623
# 03:24:56 10/08/15 BRT - Processing combination ('location', 'nu_info', 'raw_scores')
# 03:24:56 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:24:56 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 260)
# 03:24:56 10/08/15 BRT - Test shape (64, 259)
# 03:24:56 10/08/15 BRT - Created train and validation
# 03:24:56 10/08/15 BRT - Size train: (513, 259) test:(57, 259)
# 03:24:56 10/08/15 BRT - Starting to train models
# 03:24:58 10/08/15 BRT - Took 1.18686795235 seconds
# 03:24:58 10/08/15 BRT - Val score 0.537837837838
# 03:24:58 10/08/15 BRT - Processing combination ('location', 'nu_info', 'scores_class')
# 03:24:58 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:24:58 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 259)
# 03:24:58 10/08/15 BRT - Test shape (64, 258)
# 03:24:58 10/08/15 BRT - Created train and validation
# 03:24:58 10/08/15 BRT - Size train: (513, 258) test:(57, 258)
# 03:24:58 10/08/15 BRT - Starting to train models
# 03:24:59 10/08/15 BRT - Took 1.00043320656 seconds
# 03:24:59 10/08/15 BRT - Val score 0.561977948547
# 03:24:59 10/08/15 BRT - Processing combination ('location', 'personal', 'raw_scores')
# 03:24:59 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 03:24:59 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 274)
# 03:24:59 10/08/15 BRT - Test shape (64, 273)
# 03:24:59 10/08/15 BRT - Created train and validation
# 03:24:59 10/08/15 BRT - Size train: (513, 273) test:(57, 273)
# 03:24:59 10/08/15 BRT - Starting to train models
# 03:25:00 10/08/15 BRT - Took 1.72773003578 seconds
# 03:25:00 10/08/15 BRT - Val score 0.518831168831
# 03:25:00 10/08/15 BRT - Processing combination ('location', 'personal', 'scores_class')
# 03:25:00 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 03:25:00 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 273)
# 03:25:00 10/08/15 BRT - Test shape (64, 272)
# 03:25:00 10/08/15 BRT - Created train and validation
# 03:25:00 10/08/15 BRT - Size train: (513, 272) test:(57, 272)
# 03:25:00 10/08/15 BRT - Starting to train models
# 03:25:02 10/08/15 BRT - Took 1.6650519371 seconds
# 03:25:02 10/08/15 BRT - Val score 0.570586308549
# 03:25:02 10/08/15 BRT - Processing combination ('location', 'raw_scores', 'scores_class')
# 03:25:02 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 252)
# 03:25:02 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 256)
# 03:25:02 10/08/15 BRT - Test shape (64, 255)
# 03:25:02 10/08/15 BRT - Created train and validation
# 03:25:02 10/08/15 BRT - Size train: (513, 255) test:(57, 255)
# 03:25:02 10/08/15 BRT - Starting to train models
# 03:25:04 10/08/15 BRT - Took 1.50213003159 seconds
# 03:25:04 10/08/15 BRT - Val score 0.570586308549
# 03:25:04 10/08/15 BRT - Processing combination ('nu_info', 'personal', 'raw_scores')
# 03:25:04 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 03:25:04 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 36)
# 03:25:04 10/08/15 BRT - Test shape (64, 35)
# 03:25:04 10/08/15 BRT - Created train and validation
# 03:25:04 10/08/15 BRT - Size train: (513, 35) test:(57, 35)
# 03:25:04 10/08/15 BRT - Starting to train models
# 03:25:04 10/08/15 BRT - Took 0.53297495842 seconds
# 03:25:04 10/08/15 BRT - Val score 0.604166666667
# 03:25:04 10/08/15 BRT - Processing combination ('nu_info', 'personal', 'scores_class')
# 03:25:04 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 03:25:04 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 35)
# 03:25:04 10/08/15 BRT - Test shape (64, 34)
# 03:25:04 10/08/15 BRT - Created train and validation
# 03:25:04 10/08/15 BRT - Size train: (513, 34) test:(57, 34)
# 03:25:04 10/08/15 BRT - Starting to train models
# 03:25:05 10/08/15 BRT - Took 0.489038944244 seconds
# 03:25:05 10/08/15 BRT - Val score 0.5725
# 03:25:05 10/08/15 BRT - Processing combination ('nu_info', 'raw_scores', 'scores_class')
# 03:25:05 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 14)
# 03:25:05 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 18)
# 03:25:05 10/08/15 BRT - Test shape (64, 17)
# 03:25:05 10/08/15 BRT - Created train and validation
# 03:25:05 10/08/15 BRT - Size train: (513, 17) test:(57, 17)
# 03:25:05 10/08/15 BRT - Starting to train models
# 03:25:05 10/08/15 BRT - Took 0.429364919662 seconds
# 03:25:05 10/08/15 BRT - Val score 0.577777777778
# 03:25:05 10/08/15 BRT - Processing combination ('personal', 'raw_scores', 'scores_class')
# 03:25:05 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 28)
# 03:25:05 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 32)
# 03:25:05 10/08/15 BRT - Test shape (64, 31)
# 03:25:05 10/08/15 BRT - Created train and validation
# 03:25:05 10/08/15 BRT - Size train: (513, 31) test:(57, 31)
# 03:25:05 10/08/15 BRT - Starting to train models
# 03:25:06 10/08/15 BRT - Took 0.742607116699 seconds
# 03:25:06 10/08/15 BRT - Val score 0.547619047619
# 03:25:06 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info', 'personal')
# 03:25:06 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:06 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:25:06 10/08/15 BRT - Loaded info group personal, current shape of data (634, 286)
# 03:25:06 10/08/15 BRT - Test shape (64, 285)
# 03:25:06 10/08/15 BRT - Created train and validation
# 03:25:06 10/08/15 BRT - Size train: (513, 285) test:(57, 285)
# 03:25:06 10/08/15 BRT - Starting to train models
# 03:25:07 10/08/15 BRT - Took 1.0707821846 seconds
# 03:25:07 10/08/15 BRT - Val score 0.570586308549
# 03:25:07 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info', 'raw_scores')
# 03:25:07 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:07 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:25:07 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 269)
# 03:25:07 10/08/15 BRT - Test shape (64, 268)
# 03:25:07 10/08/15 BRT - Created train and validation
# 03:25:07 10/08/15 BRT - Size train: (513, 268) test:(57, 268)
# 03:25:07 10/08/15 BRT - Starting to train models
# 03:25:08 10/08/15 BRT - Took 1.01689195633 seconds
# 03:25:08 10/08/15 BRT - Val score 0.559232910609
# 03:25:08 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info', 'scores_class')
# 03:25:08 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:08 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:25:08 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 268)
# 03:25:08 10/08/15 BRT - Test shape (64, 267)
# 03:25:08 10/08/15 BRT - Created train and validation
# 03:25:08 10/08/15 BRT - Size train: (513, 267) test:(57, 267)
# 03:25:08 10/08/15 BRT - Starting to train models
# 03:25:09 10/08/15 BRT - Took 0.879385948181 seconds
# 03:25:09 10/08/15 BRT - Val score 0.559232910609
# 03:25:09 10/08/15 BRT - Processing combination ('balance', 'location', 'personal', 'raw_scores')
# 03:25:09 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:09 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 03:25:09 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 283)
# 03:25:09 10/08/15 BRT - Test shape (64, 282)
# 03:25:09 10/08/15 BRT - Created train and validation
# 03:25:09 10/08/15 BRT - Size train: (513, 282) test:(57, 282)
# 03:25:09 10/08/15 BRT - Starting to train models
# 03:25:10 10/08/15 BRT - Took 1.04634809494 seconds
# 03:25:10 10/08/15 BRT - Val score 0.5725
# 03:25:10 10/08/15 BRT - Processing combination ('balance', 'location', 'personal', 'scores_class')
# 03:25:10 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:10 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 03:25:10 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 282)
# 03:25:10 10/08/15 BRT - Test shape (64, 281)
# 03:25:10 10/08/15 BRT - Created train and validation
# 03:25:10 10/08/15 BRT - Size train: (513, 281) test:(57, 281)
# 03:25:10 10/08/15 BRT - Starting to train models
# 03:25:11 10/08/15 BRT - Took 1.18110108376 seconds
# 03:25:11 10/08/15 BRT - Val score 0.588383045526
# 03:25:11 10/08/15 BRT - Processing combination ('balance', 'location', 'raw_scores', 'scores_class')
# 03:25:12 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:12 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 261)
# 03:25:12 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 265)
# 03:25:12 10/08/15 BRT - Test shape (64, 264)
# 03:25:12 10/08/15 BRT - Created train and validation
# 03:25:12 10/08/15 BRT - Size train: (513, 264) test:(57, 264)
# 03:25:12 10/08/15 BRT - Starting to train models
# 03:25:12 10/08/15 BRT - Took 0.87787103653 seconds
# 03:25:12 10/08/15 BRT - Val score 0.541062801932
# 03:25:12 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'personal', 'raw_scores')
# 03:25:12 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:25:12 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 03:25:12 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 45)
# 03:25:12 10/08/15 BRT - Test shape (64, 44)
# 03:25:12 10/08/15 BRT - Created train and validation
# 03:25:12 10/08/15 BRT - Size train: (513, 44) test:(57, 44)
# 03:25:12 10/08/15 BRT - Starting to train models
# 03:25:13 10/08/15 BRT - Took 0.522521972656 seconds
# 03:25:13 10/08/15 BRT - Val score 0.568181818182
# 03:25:13 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'personal', 'scores_class')
# 03:25:13 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:25:13 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 03:25:13 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 44)
# 03:25:13 10/08/15 BRT - Test shape (64, 43)
# 03:25:13 10/08/15 BRT - Created train and validation
# 03:25:13 10/08/15 BRT - Size train: (513, 43) test:(57, 43)
# 03:25:13 10/08/15 BRT - Starting to train models
# 03:25:13 10/08/15 BRT - Took 0.488415002823 seconds
# 03:25:13 10/08/15 BRT - Val score 0.504347826087
# 03:25:13 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'raw_scores', 'scores_class')
# 03:25:13 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:25:13 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 23)
# 03:25:13 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 27)
# 03:25:13 10/08/15 BRT - Test shape (64, 26)
# 03:25:13 10/08/15 BRT - Created train and validation
# 03:25:13 10/08/15 BRT - Size train: (513, 26) test:(57, 26)
# 03:25:13 10/08/15 BRT - Starting to train models
# 03:25:14 10/08/15 BRT - Took 0.504088163376 seconds
# 03:25:14 10/08/15 BRT - Val score 0.559232910609
# 03:25:14 10/08/15 BRT - Processing combination ('balance', 'personal', 'raw_scores', 'scores_class')
# 03:25:14 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 03:25:14 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 37)
# 03:25:14 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 41)
# 03:25:14 10/08/15 BRT - Test shape (64, 40)
# 03:25:14 10/08/15 BRT - Created train and validation
# 03:25:14 10/08/15 BRT - Size train: (513, 40) test:(57, 40)
# 03:25:14 10/08/15 BRT - Starting to train models
# 03:25:14 10/08/15 BRT - Took 0.452889919281 seconds
# 03:25:14 10/08/15 BRT - Val score 0.52621483376
# 03:25:14 10/08/15 BRT - Processing combination ('location', 'nu_info', 'personal', 'raw_scores')
# 03:25:15 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:25:15 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 03:25:15 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 282)
# 03:25:15 10/08/15 BRT - Test shape (64, 281)
# 03:25:15 10/08/15 BRT - Created train and validation
# 03:25:15 10/08/15 BRT - Size train: (513, 281) test:(57, 281)
# 03:25:15 10/08/15 BRT - Starting to train models
# 03:25:16 10/08/15 BRT - Took 1.17061185837 seconds
# 03:25:16 10/08/15 BRT - Val score 0.526315789474
# 03:25:16 10/08/15 BRT - Processing combination ('location', 'nu_info', 'personal', 'scores_class')
# 03:25:16 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:25:16 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 03:25:16 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 281)
# 03:25:16 10/08/15 BRT - Test shape (64, 280)
# 03:25:16 10/08/15 BRT - Created train and validation
# 03:25:16 10/08/15 BRT - Size train: (513, 280) test:(57, 280)
# 03:25:16 10/08/15 BRT - Starting to train models
# 03:25:17 10/08/15 BRT - Took 1.50767111778 seconds
# 03:25:17 10/08/15 BRT - Val score 0.624175824176
# 03:25:17 10/08/15 BRT - Processing combination ('location', 'nu_info', 'raw_scores', 'scores_class')
# 03:25:17 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:25:17 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 260)
# 03:25:17 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 264)
# 03:25:17 10/08/15 BRT - Test shape (64, 263)
# 03:25:17 10/08/15 BRT - Created train and validation
# 03:25:17 10/08/15 BRT - Size train: (513, 263) test:(57, 263)
# 03:25:17 10/08/15 BRT - Starting to train models
# 03:25:18 10/08/15 BRT - Took 1.09089398384 seconds
# 03:25:18 10/08/15 BRT - Val score 0.547475389012
# 03:25:18 10/08/15 BRT - Processing combination ('location', 'personal', 'raw_scores', 'scores_class')
# 03:25:18 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 03:25:18 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 274)
# 03:25:18 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 278)
# 03:25:18 10/08/15 BRT - Test shape (64, 277)
# 03:25:18 10/08/15 BRT - Created train and validation
# 03:25:18 10/08/15 BRT - Size train: (513, 277) test:(57, 277)
# 03:25:18 10/08/15 BRT - Starting to train models
# 03:25:20 10/08/15 BRT - Took 1.61290311813 seconds
# 03:25:20 10/08/15 BRT - Val score 0.496212121212
# 03:25:20 10/08/15 BRT - Processing combination ('nu_info', 'personal', 'raw_scores', 'scores_class')
# 03:25:20 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 03:25:20 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 36)
# 03:25:20 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 40)
# 03:25:20 10/08/15 BRT - Test shape (64, 39)
# 03:25:20 10/08/15 BRT - Created train and validation
# 03:25:20 10/08/15 BRT - Size train: (513, 39) test:(57, 39)
# 03:25:20 10/08/15 BRT - Starting to train models
# 03:25:21 10/08/15 BRT - Took 0.590095996857 seconds
# 03:25:21 10/08/15 BRT - Val score 0.568181818182
# 03:25:21 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info', 'personal', 'raw_scores')
# 03:25:21 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:21 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:25:21 10/08/15 BRT - Loaded info group personal, current shape of data (634, 286)
# 03:25:21 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 291)
# 03:25:21 10/08/15 BRT - Test shape (64, 290)
# 03:25:21 10/08/15 BRT - Created train and validation
# 03:25:21 10/08/15 BRT - Size train: (513, 290) test:(57, 290)
# 03:25:21 10/08/15 BRT - Starting to train models
# 03:25:22 10/08/15 BRT - Took 1.28552603722 seconds
# 03:25:22 10/08/15 BRT - Val score 0.516797488226
# 03:25:22 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info', 'personal', 'scores_class')
# 03:25:22 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:22 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:25:22 10/08/15 BRT - Loaded info group personal, current shape of data (634, 286)
# 03:25:22 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 290)
# 03:25:22 10/08/15 BRT - Test shape (64, 289)
# 03:25:22 10/08/15 BRT - Created train and validation
# 03:25:22 10/08/15 BRT - Size train: (513, 289) test:(57, 289)
# 03:25:22 10/08/15 BRT - Starting to train models
# 03:25:23 10/08/15 BRT - Took 1.26262998581 seconds
# 03:25:23 10/08/15 BRT - Val score 0.518831168831
# 03:25:23 10/08/15 BRT - Processing combination ('balance', 'location', 'nu_info', 'raw_scores', 'scores_class')
# 03:25:23 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:23 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 03:25:23 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 269)
# 03:25:23 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 273)
# 03:25:23 10/08/15 BRT - Test shape (64, 272)
# 03:25:23 10/08/15 BRT - Created train and validation
# 03:25:23 10/08/15 BRT - Size train: (513, 272) test:(57, 272)
# 03:25:23 10/08/15 BRT - Starting to train models
# 03:25:24 10/08/15 BRT - Took 0.923017024994 seconds
# 03:25:24 10/08/15 BRT - Val score 0.559232910609
# 03:25:24 10/08/15 BRT - Processing combination ('balance', 'location', 'personal', 'raw_scores', 'scores_class')
# 03:25:24 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 03:25:24 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 03:25:24 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 283)
# 03:25:24 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 287)
# 03:25:24 10/08/15 BRT - Test shape (64, 286)
# 03:25:24 10/08/15 BRT - Created train and validation
# 03:25:24 10/08/15 BRT - Size train: (513, 286) test:(57, 286)
# 03:25:24 10/08/15 BRT - Starting to train models
# 03:25:25 10/08/15 BRT - Took 1.03449082375 seconds
# 03:25:25 10/08/15 BRT - Val score 0.585317460317
# 03:25:25 10/08/15 BRT - Processing combination ('balance', 'nu_info', 'personal', 'raw_scores', 'scores_class')
# 03:25:25 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 03:25:25 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 03:25:25 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 45)
# 03:25:25 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 49)
# 03:25:25 10/08/15 BRT - Test shape (64, 48)
# 03:25:25 10/08/15 BRT - Created train and validation
# 03:25:25 10/08/15 BRT - Size train: (513, 48) test:(57, 48)
# 03:25:25 10/08/15 BRT - Starting to train models
# 03:25:26 10/08/15 BRT - Took 0.521733999252 seconds
# 03:25:26 10/08/15 BRT - Val score 0.518831168831
# 03:25:26 10/08/15 BRT - Processing combination ('location', 'nu_info', 'personal', 'raw_scores', 'scores_class')
# 03:25:26 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 03:25:26 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 03:25:26 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 282)
# 03:25:26 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 286)
# 03:25:26 10/08/15 BRT - Test shape (64, 285)
# 03:25:26 10/08/15 BRT - Created train and validation
# 03:25:26 10/08/15 BRT - Size train: (513, 285) test:(57, 285)
# 03:25:26 10/08/15 BRT - Starting to train models
# 03:25:28 10/08/15 BRT - Took 1.45726919174 seconds
# 03:25:28 10/08/15 BRT - Val score 0.537837837838

# %%
print_time('Best run is:')
print_time('Comb: {}'.format(best_run['comb']))
print_time('Model: {}'.format(best_run['model']))
print_time('Scores: train - {} :: validation - {} :: test - {}'.
           format(best_run['score_train'], best_run['score_val'], best_run['score_test']))
mu.classification_report_matrix(best_run['y_test'], best_run['pred_test'])
# Out:
# 03:16:54 10/08/15 BRT - Best run is:
# 03:16:54 10/08/15 BRT - Comb: ('balance', 'nu_info', 'raw_scores')
# 03:16:54 10/08/15 BRT - Model: ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=56909, verbose=0,
#            warm_start=False)
# 03:16:54 10/08/15 BRT - Scores: train - 1.0 :: validation - 0.591970121382 :: test - 0.615615615616
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a06c5065db0e> in <module>()
#       4 print_time('Scores: train - {} :: validation - {} :: test - {}'.
#       5            format(best_run['score_train'], best_run['score_val'], best_run['score_test']))
# ----> 6 mu.classification_report_matrix(best_run['y_test'], best_run['pred_test'])
#
# KeyError: 'y_test'

# %%
best_run.keys()
# Out:
# ['X_val',
#  'score_val',
#  'X_train',
#  'score_test',
#  'score_train',
#  'pred_test',
#  'pred_train',
#  'pred_val',
#  'y_val',
#  'y_tr',
#  'comb',
#  'model']

# %%
num_best = 3
for score in sort(best_models.keys())[-num_best-2:-2]:
    model = best_models[score]
    print_time('Comb: {}'.format(model['comb']))
    print_time('Model: {}'.format(model['model']))
    print_time('Scores: train - {} :: validation - {} :: test - {}'.
               format(model['score_train'], model['score_val'], best_run['score_test']))
    mu.classification_report_matrix(best_run['y_test'], best_run['pred_test'])

# %% [markdown]
# ### Conclusion
#     Svc is still the best algorithm but the column configurations changed. The next 3 best algorithms also changed.

# %%
import shlex, subprocess

# vw files
vw_file_train = './Processed/data.vw.train.txt'
vw_file_val = './Processed/data.vw.val.txt'
vw_file_test = './Processed/data.vw.test.txt'

# grid search the column groups
best_model = {'group': comb, 'score_test': 0, 'pred_test':None, 
                      'score_val': 0, 'pred_val':None}
for comb in all_combinations:
    # load the data groups and split them
    data = mu.load_data(comb, del_key=False)
    
    # create test set
    X_train, X_test, y_train, y_test = mu.split_data(data, target)
    print_time('Test shape {}'.format(X_test.shape))
    
    # create the validation set
    X_train, X_val, y_train, y_val = mu.split_data(X_train, y_train)
    
    # join the y value and write the file in VW format
    vw_data = pd.concat([X_train, y_train], axis=1)
    vw_val = pd.concat([X_val, y_val], axis=1)
    vw_test = pd.concat([X_test, y_test], axis=1)
    
    print_time('Shape of train: {}, shape of test: {}'.format(vw_data.shape, vw_val.shape))
    mu.df_to_vw(vw_data, vw_file_train, 'target', id_col='customer_id')
    mu.df_to_vw(vw_val, vw_file_val, 'target', id_col='customer_id')
    mu.df_to_vw(vw_test, vw_file_test, 'target', id_col='customer_id')
    
    # run the vw process externally
    print_time(comb) 
    p = subprocess.Popen(["./go_vw.sh", "10", ""], 
                     stdout=subprocess.PIPE,
                    stderr=subprocess.PIPE)
    print_time(p.communicate()[0])

    # get the results to compare
    pred = pd.read_csv('./val.vw.txt', sep= ' ', header=None, names=['Pred', 'costumer_id'])
    pred.columns = ['Pred', 'customer_id']
    pred['preds'] = pred.Pred.apply(lambda l: 0 if l<0 else 1 )
    joined = pd.merge(pred, vw_val[['customer_id', 'target']],left_on='customer_id', 
                       right_on='customer_id', how='left')
    
    # print the results
    print_time('Validation scores')
    mu.classification_report_matrix(joined.target, joined.preds )
    score_val = mu.f1_scorer(joined.target, joined.preds)
    
    print_time(comb) 
    p = subprocess.Popen(["./predict_vw.sh"], 
                     stdout=subprocess.PIPE,
                    stderr=subprocess.PIPE)
    print_time(p.communicate()[0])
    
    # get the results to compare
    pred_test = pd.read_csv('./pred.vw.txt', sep= ' ', header=None, names=['Pred', 'costumer_id'])
    pred_test.columns = ['Pred', 'customer_id']
    pred_test['preds'] = pred_test.Pred.apply(lambda l: 0 if l<0 else 1 )
    joined_test = pd.merge(pred_test, vw_test[['customer_id', 'target']],left_on='customer_id', 
                       right_on='customer_id', how='left')
    
    # print the results
    print_time('Test scores')
    mu.classification_report_matrix(joined_test.target, joined_test.preds)
    score_test = mu.f1_scorer(joined_test.target, joined_test.preds)
    print_time('Score of test {}'.format(score_test))
    
    # save if this is the best model
    if score_test > best_model['score_test']:
        best_model = {'group': comb, 'score_test': score_test, 'pred_test':joined_test.preds, 
                      'score_val': score_val, 'pred_val':joined.preds}

# %%
print best_model['score_test']
print best_model['group']
