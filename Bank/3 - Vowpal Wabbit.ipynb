# %% [markdown]
# # Vowpal Wabbit
# This script uses the [Vowpal Wabbit](http://hunch.net/~vw/) algorithm to predict the classes good or bad. The steps are:
#
#     - load the data
#     - create a combination of all the groups of columns
#     - train and predict the model. Save the best and save the predictions to the Output folder
#     - for the best combination of group, check other parameters like loss function and l1 and l2 regularization parameters
#
# It was created a function called df_to_vw to save a Pandas DataFrame into VW file format. For the trainning and predicting part, the VW is called externally using Python's `subprocess` module that calls a `Sheel Script`.

# %%
import pandas as pd
import mylib.utils as mu
from mylib.utils import print_time
import sklearn.metrics as metrics
from itertools import combinations 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import f1_score
import shlex, subprocess

# %%
proc_name = 'VW_all'
vw_file_train = './Processed/data.vw.train.txt'
vw_file_val = './Processed/data.vw.val.txt'
vw_file_test = './Processed/data.vw.test.txt'
target = mu.load_target_data()

# %% [markdown]
# ### Grid search different column groups

# %%
# groups to test and their combination
groups = ['balance', 'location', 'nu_info', 'personal', 'raw_scores', 'scores_class']
all_combinations = [ p for i in range(len(groups)) for p in combinations(groups, i)][1:]

# %%
# grid search the column groups
best_model = {'group': None, 'score_val': 0}
for comb in all_combinations:
    # load the data groups and split them
    data = mu.load_data(comb, del_key=False)
    X_train, X_val, y_train, y_val = mu.split_data(data, target)
    
    # join the y value and write the file in VW format
    vw_data = pd.concat([X_train, y_train], axis=1)
    vw_val = pd.concat([X_val, y_val], axis=1)
    print_time('Shape of train: {}, shape of test: {}'.format(vw_data.shape, vw_val.shape))
    mu.df_to_vw(vw_data, vw_file_train, 'target', id_col='customer_id')
    mu.df_to_vw(vw_val, vw_file_val, 'target', id_col='customer_id')
    #mu.df_to_vw(vw_test, vw_file_test, 'target', id_col='customer_id')
    
    # run the vw process externally
    print_time(comb) 
    p = subprocess.Popen(["./go_vw.sh", "10", ""], 
                     stdout=subprocess.PIPE,
                    stderr=subprocess.PIPE)
    print_time(p.communicate()[0])

    # get the results to compare
    pred = pd.read_csv('./val.vw.txt', sep= ' ', header=None, names=['Pred', 'costumer_id'])
    pred.columns = ['Pred', 'customer_id']
    pred['preds'] = pred.Pred.apply(lambda l: 0 if l<0 else 1 )
    joined = pd.merge(pred, vw_val[['customer_id', 'target']],left_on='customer_id', 
                       right_on='customer_id', how='left')
    
    # print the results
    print_time('Validation scores')
    mu.classification_report_matrix(joined.target, joined.preds )
    score = mu.f1_scorer(joined.target, joined.preds)
    
    # save if this is the best model
    if score > best_model['score_val']:
        best_model = {'group': comb, 'score_val': score, 
                      'pred_val': joined.preds, 'model':mu.VowpalWabbit()}
# Out:
# 02:52:00 10/08/15 BRT - Shape of train: (570, 11), shape of test: (64, 11)
# 02:52:00 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:00 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:00 10/08/15 BRT - ('balance',)
# 02:52:00 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:00 10/08/15 BRT - Validation scores
# 02:52:00 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      1.00      0.65        31
#           1       0.00      0.00      0.00        33
#
# avg / total       0.23      0.48      0.32        64
#
# 02:52:00 10/08/15 BRT -
#  [[31  0]
#  [33  0]]
# 02:52:00 10/08/15 BRT - Shape of train: (570, 248), shape of test: (64, 248)
# 02:52:01 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:01 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:01 10/08/15 BRT - ('location',)
# 02:52:02 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:02 10/08/15 BRT - Validation scores
# 02:52:02 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.58      0.84      0.68        31
#           1       0.74      0.42      0.54        33
#
# avg / total       0.66      0.62      0.61        64
#
# 02:52:02 10/08/15 BRT -
#  [[26  5]
#  [19 14]]
# 02:52:02 10/08/15 BRT - Shape of train: (570, 10), shape of test: (64, 10)
# 02:52:02 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:02 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:02 10/08/15 BRT - ('nu_info',)
# 02:52:02 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:02 10/08/15 BRT - Validation scores
# 02:52:02 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.46      0.77      0.58        31
#           1       0.42      0.15      0.22        33
#
# avg / total       0.44      0.45      0.39        64
#
# 02:52:02 10/08/15 BRT -
#  [[24  7]
#  [28  5]]
# 02:52:02 10/08/15 BRT - Shape of train: (570, 24), shape of test: (64, 24)
# 02:52:03 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:03 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:03 10/08/15 BRT - ('personal',)
# 02:52:03 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:03 10/08/15 BRT - Validation scores
# 02:52:03 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67        31
#           1       1.00      0.06      0.11        33
#
# avg / total       0.76      0.52      0.38        64
#
# 02:52:03 10/08/15 BRT -
#  [[31  0]
#  [31  2]]
# 02:52:03 10/08/15 BRT - Shape of train: (570, 7), shape of test: (64, 7)
# 02:52:03 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:03 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:03 10/08/15 BRT - ('raw_scores',)
# 02:52:03 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:03 10/08/15 BRT - Validation scores
# 02:52:03 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      1.00      0.65        31
#           1       0.00      0.00      0.00        33
#
# avg / total       0.23      0.48      0.32        64
#
# 02:52:03 10/08/15 BRT -
#  [[31  0]
#  [33  0]]
# 02:52:03 10/08/15 BRT - Shape of train: (570, 6), shape of test: (64, 6)
# 02:52:04 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:04 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:04 10/08/15 BRT - ('scores_class',)
# 02:52:04 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:04 10/08/15 BRT - Validation scores
# 02:52:04 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:04 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:04 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:04 10/08/15 BRT - Shape of train: (570, 257), shape of test: (64, 257)
# 02:52:05 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:05 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:05 10/08/15 BRT - ('balance', 'location')
# 02:52:05 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:05 10/08/15 BRT - Validation scores
# 02:52:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.58      0.84      0.68        31
#           1       0.74      0.42      0.54        33
#
# avg / total       0.66      0.62      0.61        64
#
# 02:52:05 10/08/15 BRT -
#  [[26  5]
#  [19 14]]
# 02:52:05 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:05 10/08/15 BRT - Shape of train: (570, 19), shape of test: (64, 19)
# 02:52:06 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:06 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:06 10/08/15 BRT - ('balance', 'nu_info')
# 02:52:06 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:06 10/08/15 BRT - Validation scores
# 02:52:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.46      0.77      0.58        31
#           1       0.42      0.15      0.22        33
#
# avg / total       0.44      0.45      0.39        64
#
# 02:52:06 10/08/15 BRT -
#  [[24  7]
#  [28  5]]
# 02:52:06 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 02:52:06 10/08/15 BRT - Shape of train: (570, 33), shape of test: (64, 33)
# 02:52:07 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:07 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:07 10/08/15 BRT - ('balance', 'personal')
# 02:52:07 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:07 10/08/15 BRT - Validation scores
# 02:52:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67        31
#           1       1.00      0.06      0.11        33
#
# avg / total       0.76      0.52      0.38        64
#
# 02:52:07 10/08/15 BRT -
#  [[31  0]
#  [31  2]]
# 02:52:07 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 15)
# 02:52:07 10/08/15 BRT - Shape of train: (570, 16), shape of test: (64, 16)
# 02:52:07 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:07 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:07 10/08/15 BRT - ('balance', 'raw_scores')
# 02:52:08 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:08 10/08/15 BRT - Validation scores
# 02:52:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      1.00      0.65        31
#           1       0.00      0.00      0.00        33
#
# avg / total       0.23      0.48      0.32        64
#
# 02:52:08 10/08/15 BRT -
#  [[31  0]
#  [33  0]]
# 02:52:08 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 14)
# 02:52:08 10/08/15 BRT - Shape of train: (570, 15), shape of test: (64, 15)
# 02:52:08 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:08 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:08 10/08/15 BRT - ('balance', 'scores_class')
# 02:52:08 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:08 10/08/15 BRT - Validation scores
# 02:52:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:08 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:08 10/08/15 BRT - Shape of train: (570, 256), shape of test: (64, 256)
# 02:52:09 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:09 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:09 10/08/15 BRT - ('location', 'nu_info')
# 02:52:10 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:10 10/08/15 BRT - Validation scores
# 02:52:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.81      0.67        31
#           1       0.70      0.42      0.53        33
#
# avg / total       0.64      0.61      0.60        64
#
# 02:52:10 10/08/15 BRT -
#  [[25  6]
#  [19 14]]
# 02:52:10 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 02:52:10 10/08/15 BRT - Shape of train: (570, 270), shape of test: (64, 270)
# 02:52:10 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:11 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:11 10/08/15 BRT - ('location', 'personal')
# 02:52:11 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:11 10/08/15 BRT - Validation scores
# 02:52:11 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      1.00      0.69        31
#           1       1.00      0.15      0.26        33
#
# avg / total       0.77      0.56      0.47        64
#
# 02:52:11 10/08/15 BRT -
#  [[31  0]
#  [28  5]]
# 02:52:11 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 252)
# 02:52:11 10/08/15 BRT - Shape of train: (570, 253), shape of test: (64, 253)
# 02:52:12 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:12 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:12 10/08/15 BRT - ('location', 'raw_scores')
# 02:52:12 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:12 10/08/15 BRT - Validation scores
# 02:52:12 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.58      0.84      0.68        31
#           1       0.74      0.42      0.54        33
#
# avg / total       0.66      0.62      0.61        64
#
# 02:52:12 10/08/15 BRT -
#  [[26  5]
#  [19 14]]
# 02:52:12 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 251)
# 02:52:12 10/08/15 BRT - Shape of train: (570, 252), shape of test: (64, 252)
# 02:52:13 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:13 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:13 10/08/15 BRT - ('location', 'scores_class')
# 02:52:13 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:13 10/08/15 BRT - Validation scores
# 02:52:13 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.73      0.71      0.72        31
#           1       0.74      0.76      0.75        33
#
# avg / total       0.73      0.73      0.73        64
#
# 02:52:13 10/08/15 BRT -
#  [[22  9]
#  [ 8 25]]
# 02:52:13 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 02:52:13 10/08/15 BRT - Shape of train: (570, 32), shape of test: (64, 32)
# 02:52:14 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:14 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:14 10/08/15 BRT - ('nu_info', 'personal')
# 02:52:14 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:14 10/08/15 BRT - Validation scores
# 02:52:14 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.51      1.00      0.67        31
#           1       1.00      0.09      0.17        33
#
# avg / total       0.76      0.53      0.41        64
#
# 02:52:14 10/08/15 BRT -
#  [[31  0]
#  [30  3]]
# 02:52:14 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 14)
# 02:52:14 10/08/15 BRT - Shape of train: (570, 15), shape of test: (64, 15)
# 02:52:14 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:14 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:14 10/08/15 BRT - ('nu_info', 'raw_scores')
# 02:52:15 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:15 10/08/15 BRT - Validation scores
# 02:52:15 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.46      0.77      0.58        31
#           1       0.42      0.15      0.22        33
#
# avg / total       0.44      0.45      0.39        64
#
# 02:52:15 10/08/15 BRT -
#  [[24  7]
#  [28  5]]
# 02:52:15 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 13)
# 02:52:15 10/08/15 BRT - Shape of train: (570, 14), shape of test: (64, 14)
# 02:52:15 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:15 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:15 10/08/15 BRT - ('nu_info', 'scores_class')
# 02:52:15 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:15 10/08/15 BRT - Validation scores
# 02:52:15 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:15 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:15 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 28)
# 02:52:15 10/08/15 BRT - Shape of train: (570, 29), shape of test: (64, 29)
# 02:52:16 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:16 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:16 10/08/15 BRT - ('personal', 'raw_scores')
# 02:52:16 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:16 10/08/15 BRT - Validation scores
# 02:52:16 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67        31
#           1       1.00      0.06      0.11        33
#
# avg / total       0.76      0.52      0.38        64
#
# 02:52:16 10/08/15 BRT -
#  [[31  0]
#  [31  2]]
# 02:52:16 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 27)
# 02:52:16 10/08/15 BRT - Shape of train: (570, 28), shape of test: (64, 28)
# 02:52:17 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:17 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:17 10/08/15 BRT - ('personal', 'scores_class')
# 02:52:17 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:17 10/08/15 BRT - Validation scores
# 02:52:17 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      0.81      0.60        31
#           1       0.50      0.18      0.27        33
#
# avg / total       0.49      0.48      0.43        64
#
# 02:52:17 10/08/15 BRT -
#  [[25  6]
#  [27  6]]
# 02:52:17 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 10)
# 02:52:17 10/08/15 BRT - Shape of train: (570, 11), shape of test: (64, 11)
# 02:52:17 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:17 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:17 10/08/15 BRT - ('raw_scores', 'scores_class')
# 02:52:17 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:17 10/08/15 BRT - Validation scores
# 02:52:18 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:18 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:18 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:18 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:18 10/08/15 BRT - Shape of train: (570, 265), shape of test: (64, 265)
# 02:52:18 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:19 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:19 10/08/15 BRT - ('balance', 'location', 'nu_info')
# 02:52:19 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:19 10/08/15 BRT - Validation scores
# 02:52:19 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.81      0.67        31
#           1       0.70      0.42      0.53        33
#
# avg / total       0.64      0.61      0.60        64
#
# 02:52:19 10/08/15 BRT -
#  [[25  6]
#  [19 14]]
# 02:52:19 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:19 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 02:52:19 10/08/15 BRT - Shape of train: (570, 279), shape of test: (64, 279)
# 02:52:20 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:20 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:20 10/08/15 BRT - ('balance', 'location', 'personal')
# 02:52:20 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:20 10/08/15 BRT - Validation scores
# 02:52:20 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      1.00      0.69        31
#           1       1.00      0.15      0.26        33
#
# avg / total       0.77      0.56      0.47        64
#
# 02:52:20 10/08/15 BRT -
#  [[31  0]
#  [28  5]]
# 02:52:20 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:20 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 261)
# 02:52:20 10/08/15 BRT - Shape of train: (570, 262), shape of test: (64, 262)
# 02:52:21 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:21 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:21 10/08/15 BRT - ('balance', 'location', 'raw_scores')
# 02:52:21 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:21 10/08/15 BRT - Validation scores
# 02:52:21 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.58      0.84      0.68        31
#           1       0.74      0.42      0.54        33
#
# avg / total       0.66      0.62      0.61        64
#
# 02:52:21 10/08/15 BRT -
#  [[26  5]
#  [19 14]]
# 02:52:21 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:22 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 260)
# 02:52:22 10/08/15 BRT - Shape of train: (570, 261), shape of test: (64, 261)
# 02:52:22 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:22 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:22 10/08/15 BRT - ('balance', 'location', 'scores_class')
# 02:52:23 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:23 10/08/15 BRT - Validation scores
# 02:52:23 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.73      0.71      0.72        31
#           1       0.74      0.76      0.75        33
#
# avg / total       0.73      0.73      0.73        64
#
# 02:52:23 10/08/15 BRT -
#  [[22  9]
#  [ 8 25]]
# 02:52:23 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:23 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 02:52:23 10/08/15 BRT - Shape of train: (570, 41), shape of test: (64, 41)
# 02:52:23 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:23 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:23 10/08/15 BRT - ('balance', 'nu_info', 'personal')
# 02:52:23 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:23 10/08/15 BRT - Validation scores
# 02:52:23 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.51      1.00      0.67        31
#           1       1.00      0.09      0.17        33
#
# avg / total       0.76      0.53      0.41        64
#
# 02:52:23 10/08/15 BRT -
#  [[31  0]
#  [30  3]]
# 02:52:23 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:23 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 23)
# 02:52:23 10/08/15 BRT - Shape of train: (570, 24), shape of test: (64, 24)
# 02:52:24 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:24 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:24 10/08/15 BRT - ('balance', 'nu_info', 'raw_scores')
# 02:52:24 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:24 10/08/15 BRT - Validation scores
# 02:52:24 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.46      0.77      0.58        31
#           1       0.42      0.15      0.22        33
#
# avg / total       0.44      0.45      0.39        64
#
# 02:52:24 10/08/15 BRT -
#  [[24  7]
#  [28  5]]
# 02:52:24 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:24 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 22)
# 02:52:24 10/08/15 BRT - Shape of train: (570, 23), shape of test: (64, 23)
# 02:52:24 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:24 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:24 10/08/15 BRT - ('balance', 'nu_info', 'scores_class')
# 02:52:25 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:25 10/08/15 BRT - Validation scores
# 02:52:25 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:25 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:25 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 02:52:25 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 37)
# 02:52:25 10/08/15 BRT - Shape of train: (570, 38), shape of test: (64, 38)
# 02:52:25 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:25 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:25 10/08/15 BRT - ('balance', 'personal', 'raw_scores')
# 02:52:25 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:25 10/08/15 BRT - Validation scores
# 02:52:25 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67        31
#           1       1.00      0.06      0.11        33
#
# avg / total       0.76      0.52      0.38        64
#
# 02:52:25 10/08/15 BRT -
#  [[31  0]
#  [31  2]]
# 02:52:25 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 02:52:25 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 36)
# 02:52:25 10/08/15 BRT - Shape of train: (570, 37), shape of test: (64, 37)
# 02:52:26 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:26 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:26 10/08/15 BRT - ('balance', 'personal', 'scores_class')
# 02:52:26 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:26 10/08/15 BRT - Validation scores
# 02:52:26 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      0.81      0.60        31
#           1       0.50      0.18      0.27        33
#
# avg / total       0.49      0.48      0.43        64
#
# 02:52:26 10/08/15 BRT -
#  [[25  6]
#  [27  6]]
# 02:52:26 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 15)
# 02:52:26 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 19)
# 02:52:26 10/08/15 BRT - Shape of train: (570, 20), shape of test: (64, 20)
# 02:52:26 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:26 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:26 10/08/15 BRT - ('balance', 'raw_scores', 'scores_class')
# 02:52:27 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:27 10/08/15 BRT - Validation scores
# 02:52:27 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:27 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:27 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:27 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 02:52:27 10/08/15 BRT - Shape of train: (570, 278), shape of test: (64, 278)
# 02:52:28 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:28 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:28 10/08/15 BRT - ('location', 'nu_info', 'personal')
# 02:52:28 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:28 10/08/15 BRT - Validation scores
# 02:52:28 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      0.97      0.68        31
#           1       0.86      0.18      0.30        33
#
# avg / total       0.70      0.56      0.48        64
#
# 02:52:28 10/08/15 BRT -
#  [[30  1]
#  [27  6]]
# 02:52:28 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:28 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 260)
# 02:52:28 10/08/15 BRT - Shape of train: (570, 261), shape of test: (64, 261)
# 02:52:29 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:29 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:29 10/08/15 BRT - ('location', 'nu_info', 'raw_scores')
# 02:52:29 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:29 10/08/15 BRT - Validation scores
# 02:52:29 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.81      0.67        31
#           1       0.70      0.42      0.53        33
#
# avg / total       0.64      0.61      0.60        64
#
# 02:52:29 10/08/15 BRT -
#  [[25  6]
#  [19 14]]
# 02:52:29 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:29 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 259)
# 02:52:29 10/08/15 BRT - Shape of train: (570, 260), shape of test: (64, 260)
# 02:52:30 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:30 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:30 10/08/15 BRT - ('location', 'nu_info', 'scores_class')
# 02:52:31 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:31 10/08/15 BRT - Validation scores
# 02:52:31 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.76      0.61      0.68        31
#           1       0.69      0.82      0.75        33
#
# avg / total       0.73      0.72      0.72        64
#
# 02:52:31 10/08/15 BRT -
#  [[19 12]
#  [ 6 27]]
# 02:52:31 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 02:52:31 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 274)
# 02:52:31 10/08/15 BRT - Shape of train: (570, 275), shape of test: (64, 275)
# 02:52:32 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:32 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:32 10/08/15 BRT - ('location', 'personal', 'raw_scores')
# 02:52:32 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:32 10/08/15 BRT - Validation scores
# 02:52:32 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      1.00      0.69        31
#           1       1.00      0.15      0.26        33
#
# avg / total       0.77      0.56      0.47        64
#
# 02:52:32 10/08/15 BRT -
#  [[31  0]
#  [28  5]]
# 02:52:32 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 02:52:32 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 273)
# 02:52:32 10/08/15 BRT - Shape of train: (570, 274), shape of test: (64, 274)
# 02:52:33 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:33 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:33 10/08/15 BRT - ('location', 'personal', 'scores_class')
# 02:52:33 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:33 10/08/15 BRT - Validation scores
# 02:52:33 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.90      0.70        31
#           1       0.80      0.36      0.50        33
#
# avg / total       0.69      0.62      0.60        64
#
# 02:52:33 10/08/15 BRT -
#  [[28  3]
#  [21 12]]
# 02:52:33 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 252)
# 02:52:33 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 256)
# 02:52:33 10/08/15 BRT - Shape of train: (570, 257), shape of test: (64, 257)
# 02:52:34 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:34 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:34 10/08/15 BRT - ('location', 'raw_scores', 'scores_class')
# 02:52:35 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:35 10/08/15 BRT - Validation scores
# 02:52:35 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.73      0.71      0.72        31
#           1       0.74      0.76      0.75        33
#
# avg / total       0.73      0.73      0.73        64
#
# 02:52:35 10/08/15 BRT -
#  [[22  9]
#  [ 8 25]]
# 02:52:35 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 02:52:35 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 36)
# 02:52:35 10/08/15 BRT - Shape of train: (570, 37), shape of test: (64, 37)
# 02:52:35 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:35 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:35 10/08/15 BRT - ('nu_info', 'personal', 'raw_scores')
# 02:52:35 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:35 10/08/15 BRT - Validation scores
# 02:52:35 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.51      1.00      0.67        31
#           1       1.00      0.09      0.17        33
#
# avg / total       0.76      0.53      0.41        64
#
# 02:52:35 10/08/15 BRT -
#  [[31  0]
#  [30  3]]
# 02:52:35 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 02:52:35 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 35)
# 02:52:35 10/08/15 BRT - Shape of train: (570, 36), shape of test: (64, 36)
# 02:52:36 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:36 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:36 10/08/15 BRT - ('nu_info', 'personal', 'scores_class')
# 02:52:36 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:36 10/08/15 BRT - Validation scores
# 02:52:36 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.49      0.77      0.60        31
#           1       0.53      0.24      0.33        33
#
# avg / total       0.51      0.50      0.46        64
#
# 02:52:36 10/08/15 BRT -
#  [[24  7]
#  [25  8]]
# 02:52:36 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 14)
# 02:52:36 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 18)
# 02:52:36 10/08/15 BRT - Shape of train: (570, 19), shape of test: (64, 19)
# 02:52:37 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:37 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:37 10/08/15 BRT - ('nu_info', 'raw_scores', 'scores_class')
# 02:52:37 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:37 10/08/15 BRT - Validation scores
# 02:52:37 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:37 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:37 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 28)
# 02:52:37 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 32)
# 02:52:37 10/08/15 BRT - Shape of train: (570, 33), shape of test: (64, 33)
# 02:52:37 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:37 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:37 10/08/15 BRT - ('personal', 'raw_scores', 'scores_class')
# 02:52:38 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:38 10/08/15 BRT - Validation scores
# 02:52:38 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      0.81      0.60        31
#           1       0.50      0.18      0.27        33
#
# avg / total       0.49      0.48      0.43        64
#
# 02:52:38 10/08/15 BRT -
#  [[25  6]
#  [27  6]]
# 02:52:38 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:38 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:38 10/08/15 BRT - Loaded info group personal, current shape of data (634, 286)
# 02:52:38 10/08/15 BRT - Shape of train: (570, 287), shape of test: (64, 287)
# 02:52:39 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:39 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:39 10/08/15 BRT - ('balance', 'location', 'nu_info', 'personal')
# 02:52:39 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:39 10/08/15 BRT - Validation scores
# 02:52:39 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      0.97      0.68        31
#           1       0.86      0.18      0.30        33
#
# avg / total       0.70      0.56      0.48        64
#
# 02:52:39 10/08/15 BRT -
#  [[30  1]
#  [27  6]]
# 02:52:39 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:39 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:39 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 269)
# 02:52:39 10/08/15 BRT - Shape of train: (570, 270), shape of test: (64, 270)
# 02:52:40 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:40 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:40 10/08/15 BRT - ('balance', 'location', 'nu_info', 'raw_scores')
# 02:52:40 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:40 10/08/15 BRT - Validation scores
# 02:52:40 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.81      0.67        31
#           1       0.70      0.42      0.53        33
#
# avg / total       0.64      0.61      0.60        64
#
# 02:52:40 10/08/15 BRT -
#  [[25  6]
#  [19 14]]
# 02:52:40 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:40 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:40 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 268)
# 02:52:40 10/08/15 BRT - Shape of train: (570, 269), shape of test: (64, 269)
# 02:52:41 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:41 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:41 10/08/15 BRT - ('balance', 'location', 'nu_info', 'scores_class')
# 02:52:42 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:42 10/08/15 BRT - Validation scores
# 02:52:42 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.76      0.61      0.68        31
#           1       0.69      0.82      0.75        33
#
# avg / total       0.73      0.72      0.72        64
#
# 02:52:42 10/08/15 BRT -
#  [[19 12]
#  [ 6 27]]
# 02:52:42 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:42 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 02:52:42 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 283)
# 02:52:42 10/08/15 BRT - Shape of train: (570, 284), shape of test: (64, 284)
# 02:52:42 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:43 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:43 10/08/15 BRT - ('balance', 'location', 'personal', 'raw_scores')
# 02:52:43 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:43 10/08/15 BRT - Validation scores
# 02:52:43 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      1.00      0.69        31
#           1       1.00      0.15      0.26        33
#
# avg / total       0.77      0.56      0.47        64
#
# 02:52:43 10/08/15 BRT -
#  [[31  0]
#  [28  5]]
# 02:52:43 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:43 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 02:52:43 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 282)
# 02:52:43 10/08/15 BRT - Shape of train: (570, 283), shape of test: (64, 283)
# 02:52:44 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:44 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:44 10/08/15 BRT - ('balance', 'location', 'personal', 'scores_class')
# 02:52:44 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:44 10/08/15 BRT - Validation scores
# 02:52:44 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.90      0.70        31
#           1       0.80      0.36      0.50        33
#
# avg / total       0.69      0.62      0.60        64
#
# 02:52:44 10/08/15 BRT -
#  [[28  3]
#  [21 12]]
# 02:52:44 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:44 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 261)
# 02:52:44 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 265)
# 02:52:44 10/08/15 BRT - Shape of train: (570, 266), shape of test: (64, 266)
# 02:52:45 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:45 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:45 10/08/15 BRT - ('balance', 'location', 'raw_scores', 'scores_class')
# 02:52:45 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:45 10/08/15 BRT - Validation scores
# 02:52:45 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.73      0.71      0.72        31
#           1       0.74      0.76      0.75        33
#
# avg / total       0.73      0.73      0.73        64
#
# 02:52:45 10/08/15 BRT -
#  [[22  9]
#  [ 8 25]]
# 02:52:45 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:45 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 02:52:45 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 45)
# 02:52:45 10/08/15 BRT - Shape of train: (570, 46), shape of test: (64, 46)
# 02:52:46 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:46 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:46 10/08/15 BRT - ('balance', 'nu_info', 'personal', 'raw_scores')
# 02:52:46 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:46 10/08/15 BRT - Validation scores
# 02:52:46 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.51      1.00      0.67        31
#           1       1.00      0.09      0.17        33
#
# avg / total       0.76      0.53      0.41        64
#
# 02:52:46 10/08/15 BRT -
#  [[31  0]
#  [30  3]]
# 02:52:46 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:46 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 02:52:46 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 44)
# 02:52:46 10/08/15 BRT - Shape of train: (570, 45), shape of test: (64, 45)
# 02:52:46 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:46 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:46 10/08/15 BRT - ('balance', 'nu_info', 'personal', 'scores_class')
# 02:52:47 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:47 10/08/15 BRT - Validation scores
# 02:52:47 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.49      0.77      0.60        31
#           1       0.53      0.24      0.33        33
#
# avg / total       0.51      0.50      0.46        64
#
# 02:52:47 10/08/15 BRT -
#  [[24  7]
#  [25  8]]
# 02:52:47 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:47 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 23)
# 02:52:47 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 27)
# 02:52:47 10/08/15 BRT - Shape of train: (570, 28), shape of test: (64, 28)
# 02:52:47 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:47 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:47 10/08/15 BRT - ('balance', 'nu_info', 'raw_scores', 'scores_class')
# 02:52:47 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:47 10/08/15 BRT - Validation scores
# 02:52:47 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:52:47 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# 02:52:47 10/08/15 BRT - Loaded info group personal, current shape of data (634, 32)
# 02:52:47 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 37)
# 02:52:47 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 41)
# 02:52:48 10/08/15 BRT - Shape of train: (570, 42), shape of test: (64, 42)
# 02:52:48 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:48 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:48 10/08/15 BRT - ('balance', 'personal', 'raw_scores', 'scores_class')
# 02:52:48 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:48 10/08/15 BRT - Validation scores
# 02:52:48 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.48      0.81      0.60        31
#           1       0.50      0.18      0.27        33
#
# avg / total       0.49      0.48      0.43        64
#
# 02:52:48 10/08/15 BRT -
#  [[25  6]
#  [27  6]]
# 02:52:48 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:48 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 02:52:48 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 282)
# 02:52:48 10/08/15 BRT - Shape of train: (570, 283), shape of test: (64, 283)
# 02:52:49 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:49 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:49 10/08/15 BRT - ('location', 'nu_info', 'personal', 'raw_scores')
# 02:52:49 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:49 10/08/15 BRT - Validation scores
# 02:52:49 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      0.97      0.68        31
#           1       0.86      0.18      0.30        33
#
# avg / total       0.70      0.56      0.48        64
#
# 02:52:49 10/08/15 BRT -
#  [[30  1]
#  [27  6]]
# 02:52:49 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:49 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 02:52:49 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 281)
# 02:52:49 10/08/15 BRT - Shape of train: (570, 282), shape of test: (64, 282)
# 02:52:50 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:51 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:51 10/08/15 BRT - ('location', 'nu_info', 'personal', 'scores_class')
# 02:52:51 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:51 10/08/15 BRT - Validation scores
# 02:52:51 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.87      0.69        31
#           1       0.76      0.39      0.52        33
#
# avg / total       0.67      0.62      0.60        64
#
# 02:52:51 10/08/15 BRT -
#  [[27  4]
#  [20 13]]
# 02:52:51 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:52:51 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 260)
# 02:52:51 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 264)
# 02:52:51 10/08/15 BRT - Shape of train: (570, 265), shape of test: (64, 265)
# 02:52:52 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:52 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:52 10/08/15 BRT - ('location', 'nu_info', 'raw_scores', 'scores_class')
# 02:52:52 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:52 10/08/15 BRT - Validation scores
# 02:52:52 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.76      0.61      0.68        31
#           1       0.69      0.82      0.75        33
#
# avg / total       0.73      0.72      0.72        64
#
# 02:52:52 10/08/15 BRT -
#  [[19 12]
#  [ 6 27]]
# 02:52:52 10/08/15 BRT - Loaded info group personal, current shape of data (634, 269)
# 02:52:52 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 274)
# 02:52:52 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 278)
# 02:52:52 10/08/15 BRT - Shape of train: (570, 279), shape of test: (64, 279)
# 02:52:53 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:53 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:53 10/08/15 BRT - ('location', 'personal', 'raw_scores', 'scores_class')
# 02:52:53 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:53 10/08/15 BRT - Validation scores
# 02:52:53 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.90      0.70        31
#           1       0.80      0.36      0.50        33
#
# avg / total       0.69      0.62      0.60        64
#
# 02:52:53 10/08/15 BRT -
#  [[28  3]
#  [21 12]]
# 02:52:53 10/08/15 BRT - Loaded info group personal, current shape of data (634, 31)
# 02:52:53 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 36)
# 02:52:53 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 40)
# 02:52:54 10/08/15 BRT - Shape of train: (570, 41), shape of test: (64, 41)
# 02:52:54 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:54 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:54 10/08/15 BRT - ('nu_info', 'personal', 'raw_scores', 'scores_class')
# 02:52:54 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:54 10/08/15 BRT - Validation scores
# 02:52:54 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.49      0.77      0.60        31
#           1       0.53      0.24      0.33        33
#
# avg / total       0.51      0.50      0.46        64
#
# 02:52:54 10/08/15 BRT -
#  [[24  7]
#  [25  8]]
# 02:52:54 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:54 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:54 10/08/15 BRT - Loaded info group personal, current shape of data (634, 286)
# 02:52:54 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 291)
# 02:52:54 10/08/15 BRT - Shape of train: (570, 292), shape of test: (64, 292)
# 02:52:55 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:55 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:55 10/08/15 BRT - ('balance', 'location', 'nu_info', 'personal', 'raw_scores')
# 02:52:56 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:56 10/08/15 BRT - Validation scores
# 02:52:56 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.53      0.97      0.68        31
#           1       0.86      0.18      0.30        33
#
# avg / total       0.70      0.56      0.48        64
#
# 02:52:56 10/08/15 BRT -
#  [[30  1]
#  [27  6]]
# 02:52:56 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:56 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:56 10/08/15 BRT - Loaded info group personal, current shape of data (634, 286)
# 02:52:56 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 290)
# 02:52:56 10/08/15 BRT - Shape of train: (570, 291), shape of test: (64, 291)
# 02:52:57 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:57 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:57 10/08/15 BRT - ('balance', 'location', 'nu_info', 'personal', 'scores_class')
# 02:52:57 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:57 10/08/15 BRT - Validation scores
# 02:52:57 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.87      0.69        31
#           1       0.76      0.39      0.52        33
#
# avg / total       0.67      0.62      0.60        64
#
# 02:52:57 10/08/15 BRT -
#  [[27  4]
#  [20 13]]
# 02:52:57 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:57 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 264)
# 02:52:57 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 269)
# 02:52:57 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 273)
# 02:52:57 10/08/15 BRT - Shape of train: (570, 274), shape of test: (64, 274)
# 02:52:58 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:58 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:58 10/08/15 BRT - ('balance', 'location', 'nu_info', 'raw_scores', 'scores_class')
# 02:52:58 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:58 10/08/15 BRT - Validation scores
# 02:52:58 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.76      0.61      0.68        31
#           1       0.69      0.82      0.75        33
#
# avg / total       0.73      0.72      0.72        64
#
# 02:52:58 10/08/15 BRT -
#  [[19 12]
#  [ 6 27]]
# 02:52:58 10/08/15 BRT - Loaded info group location, current shape of data (634, 256)
# 02:52:58 10/08/15 BRT - Loaded info group personal, current shape of data (634, 278)
# 02:52:58 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 283)
# 02:52:58 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 287)
# 02:52:58 10/08/15 BRT - Shape of train: (570, 288), shape of test: (64, 288)
# 02:52:59 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:52:59 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:52:59 10/08/15 BRT - ('balance', 'location', 'personal', 'raw_scores', 'scores_class')
# 02:52:59 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:52:59 10/08/15 BRT - Validation scores
# 02:52:59 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.90      0.70        31
#           1       0.80      0.36      0.50        33
#
# avg / total       0.69      0.62      0.60        64
#
# 02:52:59 10/08/15 BRT -
#  [[28  3]
#  [21 12]]
# 02:52:59 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 18)
# 02:52:59 10/08/15 BRT - Loaded info group personal, current shape of data (634, 40)
# 02:52:59 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 45)
# 02:52:59 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 49)
# 02:52:59 10/08/15 BRT - Shape of train: (570, 50), shape of test: (64, 50)
# 02:53:00 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:53:00 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:53:00 10/08/15 BRT - ('balance', 'nu_info', 'personal', 'raw_scores', 'scores_class')
# 02:53:00 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:00 10/08/15 BRT - Validation scores
# 02:53:00 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.49      0.77      0.60        31
#           1       0.53      0.24      0.33        33
#
# avg / total       0.51      0.50      0.46        64
#
# 02:53:00 10/08/15 BRT -
#  [[24  7]
#  [25  8]]
# 02:53:00 10/08/15 BRT - Loaded info group nu_info, current shape of data (634, 255)
# 02:53:00 10/08/15 BRT - Loaded info group personal, current shape of data (634, 277)
# 02:53:00 10/08/15 BRT - Loaded info group raw_scores, current shape of data (634, 282)
# 02:53:00 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 286)
# 02:53:00 10/08/15 BRT - Shape of train: (570, 287), shape of test: (64, 287)
# 02:53:01 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:53:01 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# 02:53:01 10/08/15 BRT - ('location', 'nu_info', 'personal', 'raw_scores', 'scores_class')
# 02:53:01 10/08/15 BRT - Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 10
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:01 10/08/15 BRT - Validation scores
# 02:53:01 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.57      0.87      0.69        31
#           1       0.76      0.39      0.52        33
#
# avg / total       0.67      0.62      0.60        64
#
# 02:53:01 10/08/15 BRT -
#  [[27  4]
#  [20 13]]
# /usr/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# Best model:

# %%
# print the best model
print_time('Best model {}:{}'.format(best_model['group'], best_model['score_val']))
# Out:
# 02:53:01 10/08/15 BRT - Best model ('location', 'scores_class'):0.733790066063

# %% [markdown]
# Save the model for bagging

# %%
# print the best model
mu.save_predictions_from_model(best_model, 'vw_{}'.format(best_model['group']))
# Out:
# 02:53:01 10/08/15 BRT - Saved ./Output/pred_vw_('location', 'scores_class')_733_VowpalWabbit.csv

# %% [markdown]
# Generate an output to the bagging

# %% [markdown]
# #### Grid search the other parms for the best columns combination

# %%
# tests different VW configs
loss = ['  ', '--loss_function logistic', '--loss_function hinge', '--loss_function quantile']
reg_l1 = ['  ', '--l1 0.001','--l1 0.01', '--l1 0.1','--l1 1']
reg_l2 = ['  ', '--l2 0.001','--l2 0.01', '--l2 0.1','--l2 1']
comb = ('balance', 'location', 'personal', 'raw_scores')
p_comb = [ (l,l1,l2) for l in loss for l1 in reg_l1 for l2 in reg_l2]

# %%
# load the data groups and split them
data = mu.load_data(best_model['group'], del_key=False)
X_train, X_val, y_train, y_val = mu.split_data(data, target)
    
# join the y value and write the file in VW format
vw_data = pd.concat([X_train, y_train], axis=1)
vw_val = pd.concat([X_val, y_val], axis=1)
print_time('Shape of train: {}, shape of test: {}'.format(vw_data.shape, vw_val.shape))
mu.df_to_vw(vw_data, vw_file_train, 'target', id_col='customer_id')
mu.df_to_vw(vw_val, vw_file_val, 'target', id_col='customer_id')

# restart best model
best_model_grid = {'group': None, 'score': 0}

for (loss,l1,l2) in p_comb:
    # split the params
    #loss = loss.split(' ')
    #l1 = l1.split(' ')
    #l2 = l2.split(' ')

    # run the vw process externally
    params = shlex.split("./go_vw.sh " + "15" + loss + ' ' + l1 + ' ' + l2)
    print params
    p = subprocess.Popen(params, 
                         stdout=subprocess.PIPE,
                         stderr=subprocess.PIPE)
    print p.communicate()[0]

    # get the results to compare
    pred = pd.read_csv('./val.vw.txt', sep= ' ', header=None, names=['Pred', 'costumer_id'])
    pred.columns = ['Pred', 'customer_id']
    pred['preds'] = pred.Pred.apply(lambda l: 0 if l<0 else 1 )
    joined = pd.merge(pred, vw_val[['customer_id', 'target']],left_on='customer_id', 
                       right_on='customer_id', how='left')
    
    # print the results
    print_time('Validation scores')
    mu.classification_report_matrix(joined.target, joined.preds )
    score = mu.f1_scorer(joined.target, joined.preds)
    
    # save if this is the best model
    if score > best_model_grid['score']:
        best_model_grid = {'group': (loss,l1,l2), 'score': score}
# Out:
# 02:53:01 10/08/15 BRT - Loaded info group scores_class, current shape of data (634, 251)
# 02:53:01 10/08/15 BRT - Shape of train: (570, 252), shape of test: (64, 252)
# 02:53:02 10/08/15 BRT - File written ./Processed/data.vw.train.txt
# 02:53:02 10/08/15 BRT - File written ./Processed/data.vw.val.txt
# ['./go_vw.sh', '15']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:02 10/08/15 BRT - Validation scores
# 02:53:02 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.46      0.52      0.48        31
#           1       0.48      0.42      0.45        33
#
# avg / total       0.47      0.47      0.47        64
#
# 02:53:02 10/08/15 BRT -
#  [[16 15]
#  [19 14]]
# ['./go_vw.sh', '15', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:03 10/08/15 BRT - Validation scores
# 02:53:03 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.49      0.61      0.54        31
#           1       0.52      0.39      0.45        33
#
# avg / total       0.50      0.50      0.49        64
#
# 02:53:03 10/08/15 BRT -
#  [[19 12]
#  [20 13]]
# ['./go_vw.sh', '15', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:03 10/08/15 BRT - Validation scores
# 02:53:03 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.46      0.61      0.53        31
#           1       0.48      0.33      0.39        33
#
# avg / total       0.47      0.47      0.46        64
#
# 02:53:03 10/08/15 BRT -
#  [[19 12]
#  [22 11]]
# ['./go_vw.sh', '15', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:03 10/08/15 BRT - Validation scores
# 02:53:03 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:03 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:04 10/08/15 BRT - Validation scores
# 02:53:04 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:04 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:04 10/08/15 BRT - Validation scores
# 02:53:04 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.52      0.39      0.44        31
#           1       0.54      0.67      0.59        33
#
# avg / total       0.53      0.53      0.52        64
#
# 02:53:04 10/08/15 BRT -
#  [[12 19]
#  [11 22]]
# ['./go_vw.sh', '15', '--l1', '0.001', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.001 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:04 10/08/15 BRT - Validation scores
# 02:53:04 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.52      0.39      0.44        31
#           1       0.54      0.67      0.59        33
#
# avg / total       0.53      0.53      0.52        64
#
# 02:53:04 10/08/15 BRT -
#  [[12 19]
#  [11 22]]
# ['./go_vw.sh', '15', '--l1', '0.001', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.001 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:04 10/08/15 BRT - Validation scores
# 02:53:04 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.49      0.61      0.54        31
#           1       0.52      0.39      0.45        33
#
# avg / total       0.50      0.50      0.49        64
#
# 02:53:04 10/08/15 BRT -
#  [[19 12]
#  [20 13]]
# ['./go_vw.sh', '15', '--l1', '0.001', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.001 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:04 10/08/15 BRT - Validation scores
# 02:53:04 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.60      0.29      0.39        31
#           1       0.55      0.82      0.66        33
#
# avg / total       0.57      0.56      0.53        64
#
# 02:53:04 10/08/15 BRT -
#  [[ 9 22]
#  [ 6 27]]
# ['./go_vw.sh', '15', '--l1', '0.001', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.001 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:05 10/08/15 BRT - Validation scores
# 02:53:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:05 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:05 10/08/15 BRT - Validation scores
# 02:53:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:05 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.01', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.01 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:05 10/08/15 BRT - Validation scores
# 02:53:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:05 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.01', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.01 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:05 10/08/15 BRT - Validation scores
# 02:53:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.60      0.19      0.29        31
#           1       0.54      0.88      0.67        33
#
# avg / total       0.57      0.55      0.49        64
#
# 02:53:05 10/08/15 BRT -
#  [[ 6 25]
#  [ 4 29]]
# ['./go_vw.sh', '15', '--l1', '0.01', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.01 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:05 10/08/15 BRT - Validation scores
# 02:53:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:05 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.01', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.01 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:05 10/08/15 BRT - Validation scores
# 02:53:05 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:05 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '0.1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 0.1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:06 10/08/15 BRT - Validation scores
# 02:53:06 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:06 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15', '--l1', '1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15 --l1 1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.001', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.001 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.001', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.001 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.001', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.001 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.001', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.001 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.01', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.01 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.01', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.01 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.01', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.01 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.01', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.01 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:07 10/08/15 BRT - Validation scores
# 02:53:07 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:07 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '0.1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 0.1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'logistic', '--l1', '1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function logistic --l1 1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.001', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.001 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.001', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.001 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.001', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.001 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.001', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.001 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.01', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.01 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.01', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.01 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.01', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.01 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:08 10/08/15 BRT - Validation scores
# 02:53:08 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:08 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.01', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.01 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '0.1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 0.1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'hinge', '--l1', '1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function hinge --l1 1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.001', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.001 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.001', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.001 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.001', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.001 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.001', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.001 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.01', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.01 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:09 10/08/15 BRT - Validation scores
# 02:53:09 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:09 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.01', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.01 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.01', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.01 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.01', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.01 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '0.1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 0.1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '1', '--l2', '0.001']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 1 --l2 0.001
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '1', '--l2', '0.01']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 1 --l2 0.01
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '1', '--l2', '0.1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 1 --l2 0.1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]
# ['./go_vw.sh', '15--loss_function', 'quantile', '--l1', '1', '--l2', '1']
# Removing old files
# Starting to process
# vw -d ./Processed/data.vw.train.txt -f normal.vw -c --passes 15--loss_function quantile --l1 1 --l2 1
# RUNNING TRAIN --------------------------
# RUNNING VALIDATION ---------------------------
#
# 02:53:10 10/08/15 BRT - Validation scores
# 02:53:10 10/08/15 BRT -
#               precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        31
#           1       0.52      1.00      0.68        33
#
# avg / total       0.27      0.52      0.35        64
#
# 02:53:10 10/08/15 BRT -
#  [[ 0 31]
#  [ 0 33]]

# %% [markdown]
# Checking if parameters achieved better results.

# %%
if best_model_grid['score'] > best_model['score']:
    print_time('Grid search for Vowpal Wabit achieved better results :') 
    print_time('last: {} grid: {}'.format(best_model['score'], best_model_grid['score']))
else:
    print_time('Grid search for Vowpal Wabit did NOT achieved better results')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-1b0911f263fc> in <module>()
# ----> 1 if best_model_grid['score'] > best_model['score']:
#       2     print_time('Grid search for Vowpal Wabit achieved better results :')
#       3     print_time('last: {} grid: {}'.format(best_model['score'], best_model_grid['score']))
#       4 else:
#       5     print_time('Grid search for Vowpal Wabit did NOT achieved better results')
#
# KeyError: 'score'

# %% [markdown]
# ## Confidence interval

# %% [markdown]
# To make sure that the technique yelds good results, the best model is run a couple of times and the condifence interval is done

# %%
comb = best_model['group']
nr_runs = 30
results = {}
for i in range(nr_runs):
    # load the data groups and split them
    data = mu.load_data(best_model['group'], del_key=False)
    X_train, X_val, y_train, y_val = mu.split_data(data, target, seed=mu.random.randint(1,10000))

    # join the y value and write the file in VW format
    vw_data = pd.concat([X_train, y_train], axis=1)
    vw_val = pd.concat([X_val, y_val], axis=1)
    print_time('Shape of train: {}, shape of test: {}'.format(vw_data.shape, vw_val.shape))
    mu.df_to_vw(vw_data, vw_file_train, 'target', id_col='customer_id')
    mu.df_to_vw(vw_val, vw_file_val, 'target', id_col='customer_id')
    
    # run the vw process externally
    print(comb) 
    p = subprocess.Popen(["./go_vw.sh", "15"], 
                     stdout=subprocess.PIPE,
                    stderr=subprocess.PIPE)
    print p.communicate()[0]

    # get the results to compare
    pred = pd.read_csv('./val.vw.txt', sep= ' ', header=None, names=['Pred', 'costumer_id'])
    pred.columns = ['Pred', 'customer_id']
    pred['preds'] = pred.Pred.apply(lambda l: 0 if l<0 else 1 )
    joined = pd.merge(pred, vw_val[['customer_id', 'target']],left_on='customer_id', 
                       right_on='customer_id', how='left')
    
    # print the results
    print_time('Validation scores')
    mu.classification_report_matrix(joined.target, joined.preds )
    score = mu.f1_scorer(joined.target, joined.preds)
    results[i] = score
    print 'Score for this run %s' %score

# %%
print 'Best Score:', mu.np.max([v for v in results.itervalues()])
print 'Worst Score:', mu.np.min([v for v in results.itervalues()])
print 'Mean:', mu.np.mean([v for v in results.itervalues()])
print 'Median:', mu.np.median([v for v in results.itervalues()])
print 'SD: ', mu.np.std([v for v in results.itervalues()])

# %% [markdown]
# ## Obs:
# A brief tutorial can be found here [Basic Tutorial](http://zinkov.com/posts/2013-08-13-vowpal-tutorial/)
